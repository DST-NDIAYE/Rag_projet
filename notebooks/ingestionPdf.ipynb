# %% [markdown]
# # PyPDFLoader

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
pdf_path = "../data/pdf_files/rapport-activite_credit_mutuelle.pdf"

# %%
loader = PyPDFLoader(pdf_path)

pdf_docs = loader.load()

# %%
len(pdf_docs)
# Out:
# 79

# %%
print(pdf_docs[2].page_content)
# Out:
# Dans un cadre d’incertitudes économique et politique,
# comment analysez-vous les résultats de 2024 ?
# Daniel Baal : Dans.ce.contexte.complexe.et.instable,.
# le.groupe.Crédit.Mutuel.réalise.d’excellents.résultats,.
# avec. un. bénéfice. net. frôlant. son. record. de. 2023..
# à.4,5.milliards.d’euros..Nous.confirmons.ainsi.notre.
# place. de. troisième. groupe. bancaire. français. ..
# Ces. performances. soulignent. l’importance. de. la.
# diversification,.de.l’innovation.et.de.l’engagement.
# envers. l’intérêt. collectif,. notamment. à. travers. le.
# partage.de.la.valeur,.pour.faire.preuve.de.résilience.
# face. aux. turbulences. politiques. et. économiques..
# Nous.sommes.solides,.tout.en.exerçant.à.plein.notre.
# responsabilité.et.notre.mission.sociale.
# Quels sont les leviers de cette performance
# financière ?
# Isabelle Ferrand : Ce. résultat. s’appuie. sur. trois .
# fondements.clés.:.une.forte.dynamique.commerciale,.
# ...

# %%
print(pdf_docs[2].metadata)
# Out:
# {'producer': 'iLovePDF', 'creator': 'Adobe InDesign 20.4 (Macintosh)', 'creationdate': '2025-07-18T16:01:37+02:00', 'moddate': '2025-07-18T16:31:45+02:00', 'trapped': '/False', 'source': '../data/pdf_files/rapport-activite_credit_mutuelle.pdf', 'total_pages': 79, 'page': 2, 'page_label': '3'}

# %% [markdown]
# # PyMuPDFLoader

# %%
from langchain_community.document_loaders import PyMuPDFLoader

# %%
loaderPyMu = PyMuPDFLoader(pdf_path)

# %%
pdf_docs = loaderPyMu.load()

# %%
print(pdf_docs[1].page_content)
# Out:
# Sommaire
#
# LE MOT DE LA PRÉSIDENCE
# ET DE LA DIRECTION GÉNÉRALE ..................p. 3
# LES TEMPS FORTS 2024 ..................................................p. 5
# 05
# 05
# Jamais à court
# d’idées ..............................p. 38
# 01
# 01
# Toujours
# plus
# coopératifs ......................p. 7
# 02
# 02
# Des
# performances
# solides ............................p. 18
# 03
# 03
# À la hauteur
# de nos
# engagements .........p. 28
# 06
# 06
# Sur tous
# les territoires ............p. 42 07
# 07
# La bancassurance
# de proximité...... .p. 48 08
# 08
# Innovation....................p. 69
# 04
# 04
# DOSSIER SPÉCIAL : LES ÉNERGIES
# COOPÉRATIVES À L’HONNEUR ....................p. 34
# 2
# RAPPORT D’ACTIVITÉS / Édition 2025
