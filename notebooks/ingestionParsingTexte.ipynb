# %% [markdown]
# # lecture fichier txt

# %%
with open("../data/texte/intro_rag.txt" , "r" , encoding="utf-8") as f :
    texte  = f.read()

# %%
print(texte)
# Out:
# TechNova est une entreprise française spécialisée dans l’intelligence artificielle et l’analyse de données.
# L’entreprise a été créée en 2018 à Paris. Elle accompagne principalement des banques, des assurances et des organismes publics.
# TechNova développe des solutions de machine learning, de traitement automatique du langage et d’intelligence artificielle générative.
# Son siège social se trouve au 25 rue de la République, 75011 Paris.

# %% [markdown]
# #  texte to doc

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content=texte , 
    metadata = { "source" : "../data/texte/intro_rag.txt" ,
                "hoteur" : "Serigne", 
                "format" : "txt"
                }
)

# %%
print(doc.page_content)
# Out:
# TechNova est une entreprise française spécialisée dans l’intelligence artificielle et l’analyse de données.
# L’entreprise a été créée en 2018 à Paris. Elle accompagne principalement des banques, des assurances et des organismes publics.
# TechNova développe des solutions de machine learning, de traitement automatique du langage et d’intelligence artificielle générative.
# Son siège social se trouve au 25 rue de la République, 75011 Paris.

# %%
print(doc.metadata["source"])
# Out:
# ../data/texte/intro_rag.txt

# %% [markdown]
# # textLoader

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("../data/texte/intro_rag.txt" , encoding="utf-8")

# %%
doc = loader.load()

# %%
print(doc[0])
# Out:
# page_content='TechNova est une entreprise française spécialisée dans l’intelligence artificielle et l’analyse de données.
# L’entreprise a été créée en 2018 à Paris. Elle accompagne principalement des banques, des assurances et des organismes publics.
# TechNova développe des solutions de machine learning, de traitement automatique du langage et d’intelligence artificielle générative.
# Son siège social se trouve au 25 rue de la République, 75011 Paris.' metadata={'source': '../data/texte/intro_rag.txt'}

# %%
doc[0].page_content
# Out:
# 'TechNova est une entreprise française spécialisée dans l’intelligence artificielle et l’analyse de données.\nL’entreprise a été créée en 2018 à Paris. Elle accompagne principalement des banques, des assurances et des organismes publics.\nTechNova développe des solutions de machine learning, de traitement automatique du langage et d’intelligence artificielle générative.\nSon siège social se trouve au 25 rue de la République, 75011 Paris.'

# %%
doc[0].metadata
# Out:
# {'source': '../data/texte/intro_rag.txt'}
